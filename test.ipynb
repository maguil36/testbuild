# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
## intializeing lemmatizer, loading json, creating lists, setting characters to ignore in our training set

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words, classes, documents = [], [] ,[]
ignore_characters = ['?', '!', ',', '.']

## organizing/clean/tokenizing json data

for intent in intents['intents']:
	for pattern in intent['patterns']:
		word_list = nltk.word_tokenize(pattern)
		words.extend(word_list)
		documents.append((word_list, intent['tag']))
		if intent['tag'] not in classes:
			classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_characters]
words = sorted(set(words))

classes = sorted(set(classes))

# print(words)

## Saving data for words/classes into pkl

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

## converting words into numerical values, shuffling, and creating model with numerical data

training = []
output_empty = [0] * len(classes)

for document in documents:
	bag = []
	word_patterns = document[0]
	word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
	for word in words:
		bag.append(1) if word in word_patterns else bag.append(0)

	output_row = list(output_empty)
	output_row[classes.index(document[1])] = 1
	training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

## training neural network

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs= 200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print('Done')
# Out:
# C:\Users\pluss\AppData\Local\Temp/ipykernel_10404/1675308999.py:49: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)
# Epoch 1/200
# 32/32 [==============================] - 0s 1ms/step - loss: 3.0027 - accuracy: 0.1500
# Epoch 2/200
# 32/32 [==============================] - 0s 1ms/step - loss: 2.6019 - accuracy: 0.2375
# Epoch 3/200
# 32/32 [==============================] - 0s 1ms/step - loss: 2.4157 - accuracy: 0.2625
# Epoch 4/200
# 32/32 [==============================] - 0s 1ms/step - loss: 2.2756 - accuracy: 0.3438
# Epoch 5/200
# 32/32 [==============================] - 0s 2ms/step - loss: 2.1299 - accuracy: 0.3562
# Epoch 6/200
# 32/32 [==============================] - 0s 2ms/step - loss: 2.0451 - accuracy: 0.3938
# Epoch 7/200
# 32/32 [==============================] - 0s 1ms/step - loss: 1.7962 - accuracy: 0.4875
# Epoch 8/200
# 32/32 [==============================] - 0s 1ms/step - loss: 1.7508 - accuracy: 0.4875
# Epoch 9/200
# 32/32 [==============================] - 0s 1ms/step - loss: 1.6221 - accuracy: 0.5188
# Epoch 10/200
# 32/32 [==============================] - 0s 1ms/step - loss: 1.4647 - accuracy: 0.5875
# Epoch 11/200
# 32/32 [==============================] - 0s 2ms/step - loss: 1.3958 - accuracy: 0.6000
# Epoch 12/200
# 32/32 [==============================] - 0s 2ms/step - loss: 1.2945 - accuracy: 0.6062
# Epoch 13/200
# 32/32 [==============================] - 0s 1ms/step - loss: 1.1661 - accuracy: 0.7125
# Epoch 14/200
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0968 - accuracy: 0.7063
# Epoch 15/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8477 - accuracy: 0.7812
# Epoch 16/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9726 - accuracy: 0.6938
# Epoch 17/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8675 - accuracy: 0.7500
# Epoch 18/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.8218 - accuracy: 0.7812
# Epoch 19/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8186 - accuracy: 0.7625
# Epoch 20/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7778 - accuracy: 0.7750
# Epoch 21/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.7524 - accuracy: 0.7750
# Epoch 22/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6800 - accuracy: 0.7812
# Epoch 23/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6916 - accuracy: 0.8062
# Epoch 24/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6681 - accuracy: 0.7875
# Epoch 25/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6149 - accuracy: 0.8250
# Epoch 26/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6012 - accuracy: 0.8188
# Epoch 27/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4884 - accuracy: 0.8625
# Epoch 28/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6214 - accuracy: 0.8188
# Epoch 29/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5451 - accuracy: 0.8687
# Epoch 30/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6411 - accuracy: 0.8188
# Epoch 31/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.5057 - accuracy: 0.8687
# Epoch 32/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4745 - accuracy: 0.8750
# Epoch 33/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4408 - accuracy: 0.8562
# Epoch 34/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4629 - accuracy: 0.8750
# Epoch 35/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4009 - accuracy: 0.9125
# Epoch 36/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4265 - accuracy: 0.8625
# Epoch 37/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4148 - accuracy: 0.8938
# Epoch 38/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4180 - accuracy: 0.8625
# Epoch 39/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3500 - accuracy: 0.9187
# Epoch 40/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3461 - accuracy: 0.9187
# Epoch 41/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3249 - accuracy: 0.9000
# Epoch 42/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3714 - accuracy: 0.8875
# Epoch 43/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3341 - accuracy: 0.9000
# Epoch 44/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3288 - accuracy: 0.8875
# Epoch 45/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3064 - accuracy: 0.9000
# Epoch 46/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2523 - accuracy: 0.9312
# Epoch 47/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2851 - accuracy: 0.9312
# Epoch 48/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3049 - accuracy: 0.9375
# Epoch 49/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3061 - accuracy: 0.9250
# Epoch 50/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2387 - accuracy: 0.9438
# Epoch 51/200
# 32/32 [==============================] - 0s 2ms/step - loss: 0.2897 - accuracy: 0.9250
# Epoch 52/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3132 - accuracy: 0.9187
# Epoch 53/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2949 - accuracy: 0.9312
# Epoch 54/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2688 - accuracy: 0.9187
# Epoch 55/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1910 - accuracy: 0.9500
# Epoch 56/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2336 - accuracy: 0.9250
# Epoch 57/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1701 - accuracy: 0.9625
# Epoch 58/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2734 - accuracy: 0.9000
# Epoch 59/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2241 - accuracy: 0.9375
# Epoch 60/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2594 - accuracy: 0.9375
# Epoch 61/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1784 - accuracy: 0.9438
# Epoch 62/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2230 - accuracy: 0.9187
# Epoch 63/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1588 - accuracy: 0.9688
# Epoch 64/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1729 - accuracy: 0.9625
# Epoch 65/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1343 - accuracy: 0.9688
# Epoch 66/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1505 - accuracy: 0.9625
# Epoch 67/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1461 - accuracy: 0.9688
# Epoch 68/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1485 - accuracy: 0.9563
# Epoch 69/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1295 - accuracy: 0.9688
# Epoch 70/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1712 - accuracy: 0.9375
# Epoch 71/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1788 - accuracy: 0.9500
# Epoch 72/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1542 - accuracy: 0.9375
# Epoch 73/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1872 - accuracy: 0.9625
# Epoch 74/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1500 - accuracy: 0.9625
# Epoch 75/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1699 - accuracy: 0.9563
# Epoch 76/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1204 - accuracy: 0.9812
# Epoch 77/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1323 - accuracy: 0.9563
# Epoch 78/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1722 - accuracy: 0.9625
# Epoch 79/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1251 - accuracy: 0.9625
# Epoch 80/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1178 - accuracy: 0.9688
# Epoch 81/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0986 - accuracy: 0.9812
# Epoch 82/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0702 - accuracy: 0.9875
# Epoch 83/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1550 - accuracy: 0.9750
# Epoch 84/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1177 - accuracy: 0.9750
# Epoch 85/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0950 - accuracy: 0.9688
# Epoch 86/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0860 - accuracy: 0.9688
# Epoch 87/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1080 - accuracy: 0.9750
# Epoch 88/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1422 - accuracy: 0.9500
# Epoch 89/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1917 - accuracy: 0.9375
# Epoch 90/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0943 - accuracy: 0.9688
# Epoch 91/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9812
# Epoch 92/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1262 - accuracy: 0.9688
# Epoch 93/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1520 - accuracy: 0.9688
# Epoch 94/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1432 - accuracy: 0.9563
# Epoch 95/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0769 - accuracy: 0.9812
# Epoch 96/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1590 - accuracy: 0.9500
# Epoch 97/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1292 - accuracy: 0.9750
# Epoch 98/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1401 - accuracy: 0.9625
# Epoch 99/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1157 - accuracy: 0.9750
# Epoch 100/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0998 - accuracy: 0.9625
# Epoch 101/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1051 - accuracy: 0.9563
# Epoch 102/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0566 - accuracy: 0.9875
# Epoch 103/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9812
# Epoch 104/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1042 - accuracy: 0.9750
# Epoch 105/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0984 - accuracy: 0.9688
# Epoch 106/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0583 - accuracy: 0.9812
# Epoch 107/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0704 - accuracy: 0.9875
# Epoch 108/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0977 - accuracy: 0.9812
# Epoch 109/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1019 - accuracy: 0.9875
# Epoch 110/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0841 - accuracy: 0.9750
# Epoch 111/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0944 - accuracy: 0.9688
# Epoch 112/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0849 - accuracy: 0.9750
# Epoch 113/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9875
# Epoch 114/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0751 - accuracy: 0.9812
# Epoch 115/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0873 - accuracy: 0.9688
# Epoch 116/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1074 - accuracy: 0.9563
# Epoch 117/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0727 - accuracy: 0.9875
# Epoch 118/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0888 - accuracy: 0.9688
# Epoch 119/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0432 - accuracy: 0.9937
# Epoch 120/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0857 - accuracy: 0.9688
# Epoch 121/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0834 - accuracy: 0.9875
# Epoch 122/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 0.9937
# Epoch 123/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9625
# Epoch 124/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0602 - accuracy: 0.9812
# Epoch 125/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0506 - accuracy: 0.9937
# Epoch 126/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 0.9875
# Epoch 127/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0964 - accuracy: 0.9688
# Epoch 128/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0574 - accuracy: 0.9875
# Epoch 129/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1346 - accuracy: 0.9563
# Epoch 130/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0727 - accuracy: 0.9750
# Epoch 131/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0463 - accuracy: 0.9875
# Epoch 132/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0730 - accuracy: 0.9750
# Epoch 133/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0514 - accuracy: 0.9937
# Epoch 134/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0587 - accuracy: 0.9875
# Epoch 135/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0984 - accuracy: 0.9750
# Epoch 136/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0758 - accuracy: 0.9812
# Epoch 137/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0837 - accuracy: 0.9812
# Epoch 138/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0713 - accuracy: 0.9750
# Epoch 139/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0777 - accuracy: 0.9750
# Epoch 140/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 141/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0835 - accuracy: 0.9812
# Epoch 142/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0684 - accuracy: 0.9812
# Epoch 143/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9750
# Epoch 144/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0351 - accuracy: 0.9937
# Epoch 145/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0637 - accuracy: 0.9812
# Epoch 146/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0627 - accuracy: 0.9812
# Epoch 147/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0841 - accuracy: 0.9812
# Epoch 148/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0521 - accuracy: 0.9812
# Epoch 149/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0554 - accuracy: 0.9937
# Epoch 150/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0804 - accuracy: 0.9750
# Epoch 151/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0376 - accuracy: 0.9875
# Epoch 152/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 153/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0662 - accuracy: 0.9688
# Epoch 154/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0387 - accuracy: 1.0000
# Epoch 155/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 0.9875
# Epoch 156/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 157/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0556 - accuracy: 0.9875
# Epoch 158/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0808 - accuracy: 0.9812
# Epoch 159/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0523 - accuracy: 0.9875
# Epoch 160/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0775 - accuracy: 0.9750
# Epoch 161/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0399 - accuracy: 0.9937
# Epoch 162/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0384 - accuracy: 0.9937
# Epoch 163/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0491 - accuracy: 0.9875
# Epoch 164/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0976 - accuracy: 0.9688
# Epoch 165/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0575 - accuracy: 0.9875
# Epoch 166/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0513 - accuracy: 0.9875
# Epoch 167/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0527 - accuracy: 0.9875
# Epoch 168/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0990 - accuracy: 0.9563
# Epoch 169/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0465 - accuracy: 0.9812
# Epoch 170/200
# 32/32 [==============================] - 0s 968us/step - loss: 0.0701 - accuracy: 0.9688
# Epoch 171/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 0.9937
# Epoch 172/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0194 - accuracy: 1.0000
# Epoch 173/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0524 - accuracy: 0.9812
# Epoch 174/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0948 - accuracy: 0.9750
# Epoch 175/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 0.9875
# Epoch 176/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 177/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0584 - accuracy: 0.9750
# Epoch 178/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0336 - accuracy: 0.9937
# Epoch 179/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0571 - accuracy: 0.9812
# Epoch 180/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0304 - accuracy: 0.9937
# Epoch 181/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0849 - accuracy: 0.9750
# Epoch 182/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0609 - accuracy: 0.9750
# Epoch 183/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1058 - accuracy: 0.9750
# Epoch 184/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0450 - accuracy: 0.9812
# Epoch 185/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0604 - accuracy: 0.9875
# Epoch 186/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0567 - accuracy: 0.9875
# Epoch 187/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0517 - accuracy: 0.9812
# Epoch 188/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0184 - accuracy: 0.9937
# Epoch 189/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0444 - accuracy: 0.9875
# Epoch 190/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0393 - accuracy: 0.9812
# Epoch 191/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0325 - accuracy: 1.0000
# Epoch 192/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0559 - accuracy: 0.9750
# Epoch 193/200
# 32/32 [==============================] - 0s 968us/step - loss: 0.0325 - accuracy: 0.9937
# Epoch 194/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0230 - accuracy: 0.9937
# Epoch 195/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0318 - accuracy: 0.9875
# Epoch 196/200
# 32/32 [==============================] - 0s 968us/step - loss: 0.0685 - accuracy: 0.9750
# Epoch 197/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0409 - accuracy: 0.9875
# Epoch 198/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0400 - accuracy: 0.9937
# Epoch 199/200
# 32/32 [==============================] - 0s 967us/step - loss: 0.0727 - accuracy: 0.9812
# Epoch 200/200
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0440 - accuracy: 0.9875
# Done

# %%
import os

from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model

from autocorrect import Speller

# %%
##loading in data from model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbot_model.h5')

spell = Speller(lang='en')

##cleaning up sentences

def clean_up_sentence(sentence):
	sentence_words = nltk.word_tokenize(sentence)
	sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
	return sentence_words

##getting bag of words

def bag_of_words(sentence):
	sentence_words = clean_up_sentence(sentence)
	bag = [0] * len(words)
	for w in sentence_words:
		for i, word in enumerate(words):
			if word == w:
				bag[i] = 1
	return np.array(bag)

##predicting class

def predict_class(sentence):
	bow = bag_of_words(sentence)
	res = model.predict(np.array([bow]))[0]
	error_threshold = .03
	results = [[i, r] for i, r in enumerate(res) if r > error_threshold]

	results.sort(key=lambda x: x[1], reverse=True)
	return_list = []
	for r in results:
		return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
	return return_list

##getting responce

def get_response(intents_list, intents_json):
	tag = intents_list[0]['intent']
	list_of_intents = intents_json['intents']
	for i in list_of_intents:
		if i['tag'] == tag:
			follow_ups_ = i['followups']
			result = [(random.choice(i['responses0'])+random.choice(i['responses1'])+random.choice(i['responses2'])).format(name), follow_ups_]
			break
	return result

# %%
def get_all_responses(var_name):
	list0_, list1_ = [], intents['intents']
	for i in list1_:
		if i['tag'] == var_name:
			for s0_ in i['responses0']:
				for s1_ in i['responses1']:
					for s2_ in i['responses2']:
						list0_.append(s0_ + s1_ + s2_)
	return(list0_)
get_all_responses('training questions')
# Out:
# []

# %%
## variable finder

def var_finder(lst, var_searching, return_var, fail_var):
    var_ = 0
    for i in lst:
        if i == var_searching:
            var_ = 1
            break
    if var_ == 1:
        return (return_var)
    else:
        return (fail_var)

## getting all responses
    
def get_all_responses(var_name):
	list0_, list1_ = [], intents['intents']
	for i in list1_:
		if i['tag'] == var_name:
			for s0_ in i['responses0']:
				for s1_ in i['responses1']:
					for s2_ in i['responses2']:
						list0_.append(s0_ + s1_ + s2_)
	return(list0_)
        

print('Bot is on, say hi!')

## remove this when you are done bridging gate between app and server
name = "Marcos"

res = 'temp'

while True:
	add_to_database = get_all_responses('add to database now')
	message = spell(input('').lower())

	## test variable, remove before release
	if message == 'break':
		print('turning off')
		break

    ## bot training and storing after training
	elif res == var_finder(add_to_database, res, res, False):
		message_0 = input('').lower()
		list_temp = []
		list_temp.append(message)
		list_temp.append(message_0)
		res = get_response([{'intent': 'training done', 'probability': '1'}], intents)[0]
		followups = get_response([{'intent': 'training done', 'probability': '1'}], intents)[1]
		print(res)
		if followups != "":
			print(followups)

	else:
		ints = predict_class(message)
        ## bot is certain enough its the correct response 
		print(float(ints[0]['probability']))
		if float(ints[0]['probability']) > .9:
			res = get_response(ints, intents)[0]
			followups = get_response(ints, intents)[1]
        ## bot is uncertain answer is correct result
		else:
			print(message)
			res = get_response([{'intent': 'bot uncertain', 'probability': '1'}], intents)[0]
			followups = get_response([{'intent': 'bot uncertain', 'probability': '1'}], intents)[1]
		print(res)
		if followups != "":
			print(followups)
# Out:
# Bot is on, say hi!
#  home
# 0.99948955
# How are you Marcos! In what way may I help you?
# ['']
#  filler
# 0.9998281
# Hey Marcos! In what way may I help you?
# ['']
#  alerts
# 0.9998677
# Hey there! In what way may I help you?
# ['']
#  goals
# 0.999816
# Hello. In what way may I help you?
# ['']
#  health
# 0.9994716
# How are you Marcos! Now how may I help you?
# ['']
#  settings
# 0.99874675
# How are you Marcos! In what way may I help you?
# ['']
#  notifications
# 0.99992454
# Hello! Now how may I help you?
# ['']
#  guardians
# 0.9996625
# Hey. Now how may I help you?
# ['']
#  contact us
# 0.9999794
# Good day Marcos! Now how may I help you?
# ['']
#  rate the kiddo
# 0.9986634
# Good day Marcos! So what do you need?
# ['']
#  about
# 0.9919578
# Hey there Marcos! In what way may I help you?
# ['']
#  break
# turning off

# %%
def predict_class(sentence):
	bow = bag_of_words(sentence)
	res = model.predict(np.array([bow]))[0]
	error_threshold = .05
	results = [[i, r] for i, r in enumerate(res) if r > error_threshold]

	results.sort(key=lambda x: x[1], reverse=True)
	return_list = []
	for r in results:
		return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
	return return_list

predict_class('')[0]
# Out:
# {'intent': 'Goals', 'probability': '0.16300383'}
