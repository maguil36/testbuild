# %%
import random
import json
import pickle
import numpy as np

import nltk
from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Dropout
from tensorflow.keras.optimizers import SGD

# %%
## intializeing lemmatizer, loading json, creating lists, setting characters to ignore in our training set

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('intents.json').read())

words, classes, documents = [], [] ,[]
ignore_characters = ['?', '!', ',', '.']

## organizing/clean/tokenizing json data

for intent in intents['intents']:
	for pattern in intent['patterns']:
		word_list = nltk.word_tokenize(pattern)
		words.extend(word_list)
		documents.append((word_list, intent['tag']))
		if intent['tag'] not in classes:
			classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignore_characters]
words = sorted(set(words))

classes = sorted(set(classes))

# print(words)

## Saving data for words/classes into pkl

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

## converting words into numerical values, shuffling, and creating model with numerical data

training = []
output_empty = [0] * len(classes)

for document in documents:
	bag = []
	word_patterns = document[0]
	word_patterns = [lemmatizer.lemmatize(word.lower()) for word in word_patterns]
	for word in words:
		bag.append(1) if word in word_patterns else bag.append(0)

	output_row = list(output_empty)
	output_row[classes.index(document[1])] = 1
	training.append([bag, output_row])

random.shuffle(training)
training = np.array(training)

train_x = list(training[:, 0])
train_y = list(training[:, 1])

## training neural network

model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)

model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs= 200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print('Done')
# Out:
# C:\Users\pluss\AppData\Local\Temp/ipykernel_12260/1675308999.py:49: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   training = np.array(training)
# c:\users\pluss\appdata\local\programs\python\python39\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# Epoch 1/200
# 118/118 [==============================] - 1s 1ms/step - loss: 4.6170 - accuracy: 0.0391
# Epoch 2/200
# 118/118 [==============================] - 0s 1ms/step - loss: 4.4668 - accuracy: 0.0731
# Epoch 3/200
# 118/118 [==============================] - 0s 1ms/step - loss: 4.3283 - accuracy: 0.0765
# Epoch 4/200
# 118/118 [==============================] - 0s 1ms/step - loss: 4.1281 - accuracy: 0.0867
# Epoch 5/200
# 118/118 [==============================] - 0s 1ms/step - loss: 3.9557 - accuracy: 0.1224
# Epoch 6/200
# 118/118 [==============================] - 0s 1ms/step - loss: 3.7395 - accuracy: 0.1293
# Epoch 7/200
# 118/118 [==============================] - 0s 1ms/step - loss: 3.4601 - accuracy: 0.1837
# Epoch 8/200
# 118/118 [==============================] - 0s 1ms/step - loss: 3.2294 - accuracy: 0.2160
# Epoch 9/200
# 118/118 [==============================] - 0s 1ms/step - loss: 3.0010 - accuracy: 0.2568
# Epoch 10/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.9031 - accuracy: 0.2602
# Epoch 11/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.6363 - accuracy: 0.3197
# Epoch 12/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.4720 - accuracy: 0.3690
# Epoch 13/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.3989 - accuracy: 0.3486
# Epoch 14/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.1955 - accuracy: 0.3861
# Epoch 15/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.1539 - accuracy: 0.4218
# Epoch 16/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.0231 - accuracy: 0.4524
# Epoch 17/200
# 118/118 [==============================] - 0s 1ms/step - loss: 2.0363 - accuracy: 0.4354
# Epoch 18/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.9146 - accuracy: 0.4660
# Epoch 19/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.8696 - accuracy: 0.4677
# Epoch 20/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.7749 - accuracy: 0.4864
# Epoch 21/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.6089 - accuracy: 0.5204
# Epoch 22/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.6151 - accuracy: 0.5272
# Epoch 23/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.6008 - accuracy: 0.5459
# Epoch 24/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.6534 - accuracy: 0.5051
# Epoch 25/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.6388 - accuracy: 0.5425
# Epoch 26/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.4771 - accuracy: 0.5544
# Epoch 27/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.4199 - accuracy: 0.5765
# Epoch 28/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.4678 - accuracy: 0.5663
# Epoch 29/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.4085 - accuracy: 0.5748
# Epoch 30/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.3477 - accuracy: 0.6003
# Epoch 31/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.3038 - accuracy: 0.6122
# Epoch 32/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.2747 - accuracy: 0.6241
# Epoch 33/200
# 118/118 [==============================] - 0s 1ms/step - loss: 1.
200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7897 - accuracy: 0.7653
# Epoch 156/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8979 - accuracy: 0.7568
# Epoch 157/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7953 - accuracy: 0.7551
# Epoch 158/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7697 - accuracy: 0.7806
# Epoch 159/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7986 - accuracy: 0.7721
# Epoch 160/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8985 - accuracy: 0.7432
# Epoch 161/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7552 - accuracy: 0.7670
# Epoch 162/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7318 - accuracy: 0.7840
# Epoch 163/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8951 - accuracy: 0.7381
# Epoch 164/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8579 - accuracy: 0.7500
# Epoch 165/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8729 - accuracy: 0.7687
# Epoch 166/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8460 - accuracy: 0.7636
# Epoch 167/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8795 - accuracy: 0.7449
# Epoch 168/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8268 - accuracy: 0.7670
# Epoch 169/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8530 - accuracy: 0.7449
# Epoch 170/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9686 - accuracy: 0.7194
# Epoch 171/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8411 - accuracy: 0.7602
# Epoch 172/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7823 - accuracy: 0.7670
# Epoch 173/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8232 - accuracy: 0.7517
# Epoch 174/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9118 - accuracy: 0.7415
# Epoch 175/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9767 - accuracy: 0.7347
# Epoch 176/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8415 - accuracy: 0.7551
# Epoch 177/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8945 - accuracy: 0.7432
# Epoch 178/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9175 - accuracy: 0.7466
# Epoch 179/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8531 - accuracy: 0.7840
# Epoch 180/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7564 - accuracy: 0.7857
# Epoch 181/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9544 - accuracy: 0.7313
# Epoch 182/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7832 - accuracy: 0.7653
# Epoch 183/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8192 - accuracy: 0.7670
# Epoch 184/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7774 - accuracy: 0.7704
# Epoch 185/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9757 - accuracy: 0.7398
# Epoch 186/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8981 - accuracy: 0.7585
# Epoch 187/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8026 - accuracy: 0.7823
# Epoch 188/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8228 - accuracy: 0.7585
# Epoch 189/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7684 - accuracy: 0.7874
# Epoch 190/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9551 - accuracy: 0.7500
# Epoch 191/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9684 - accuracy: 0.7228
# Epoch 192/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8757 - accuracy: 0.7432
# Epoch 193/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9364 - accuracy: 0.7398
# Epoch 194/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8458 - accuracy: 0.7483
# Epoch 195/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9160 - accuracy: 0.7313
# Epoch 196/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9035 - accuracy: 0.7415
# Epoch 197/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.9283 - accuracy: 0.7398
# Epoch 198/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8639 - accuracy: 0.7517
# Epoch 199/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.7940 - accuracy: 0.7755
# Epoch 200/200
# 118/118 [==============================] - 0s 2ms/step - loss: 0.8439 - accuracy: 0.7772
# Done

# %%
import os

from nltk.stem import WordNetLemmatizer

from tensorflow.keras.models import load_model

from autocorrect import Speller

# %%
##loading in data from model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbot_model.h5')

spell = Speller(lang='en')

##cleaning up sentences

def clean_up_sentence(sentence):
	sentence_words = nltk.word_tokenize(sentence)
	sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
	return sentence_words

##getting bag of words

def bag_of_words(sentence):
	sentence_words = clean_up_sentence(sentence)
	bag = [0] * len(words)
	for w in sentence_words:
		for i, word in enumerate(words):
			if word == w:
				bag[i] = 1
	return np.array(bag)

##predicting class

def predict_class(sentence):
	bow = bag_of_words(sentence)
	res = model.predict(np.array([bow]))[0]
	error_threshold = .03
	results = [[i, r] for i, r in enumerate(res) if r > error_threshold]

	results.sort(key=lambda x: x[1], reverse=True)
	return_list = []
	for r in results:
		return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
	return return_list

##getting responce

def get_response(intents_list, intents_json):
	tag = intents_list[0]['intent']
	list_of_intents = intents_json['intents']
	for i in list_of_intents:
		if i['tag'] == tag:
			follow_ups_ = i['followups']
			result = [(random.choice(i['responses0'])+random.choice(i['responses1'])+random.choice(i['responses2'])).format(name), follow_ups_]
			break
	return result

# %%
def get_all_responses(var_name):
	list0_, list1_ = [], intents['intents']
	for i in list1_:
		if i['tag'] == var_name:
			for s0_ in i['responses0']:
				for s1_ in i['responses1']:
					for s2_ in i['responses2']:
						list0_.append(s0_ + s1_ + s2_)
	return(list0_)
get_all_responses('training questions')
# Out:
# ["I start by recording your feedback. Afterwords your feedback along with everyone else's is reviewed. This then becomes new answers or better answers to your questions.",
#  "I start by recording your feedback. Afterwords your feedback along with everyone else's is reviewed. This feedback is then turned into new questions or improves old questions.",
#  "I start by recording your feedback. Afterwords your feedback along with everyone else's is reviewed. With this new answers to your questions or better answers to old questions are made.",
#  "I start by recording your feedback. Once that is done everyone's feedback is looked through. This then becomes new answers or better answers to your questions.",
#  "I start by recording your feedback. Once that is done everyone's feedback is looked through. This feedback is then turned into new questions or improves old questions.",
#  "I start by recording your feedback. Once that is done everyone's feedback is looked through. With this new answers to your questions or better answers to old questions are made.",
#  "I start by recording your feedback. Next everyone's feedback is looked over. This then becomes new answers or better answers to your questions.",
#  "I start by recording your feedback. Next everyone's feedback is looked over. This feedback is then turned into new questions or improves old questions.",
#  "I start by recording your feedback. Next everyone's feedback is looked over. With this new answers to your questions or better answers to old questions are made.",
#  "First your feedback is record. Afterwords your feedback along with everyone else's is reviewed. This then becomes new answers or better answers to your questions.",
#  "First your feedback is record. Afterwords your feedback along with everyone else's is reviewed. This feedback is then turned into new questions or improves old questions.",
#  "First your feedback is record. Afterwords your feedback along with everyone else's is reviewed. With this new answers to your questions or better answers to old questions are made.",
#  "First your feedback is record. Once that is done everyone's feedback is looked through. This then becomes new answers or better answers to your questions.",
#  "First your feedback is record. Once that is done everyone's feedback is looked through. This feedback is then turned into new questions or improves old questions.",
#  "First your feedback is record. Once that is done everyone's feedback is looked through. With this new answers to your questions or better answers to old questions are made.",
#  "First your feedback is record. Next everyone's feedback is looked over. This then becomes new answers or better answers to your questions.",
#  "First your feedback is record. Next everyone's feedback is looked over. This feedback is then turned into new questions or improves old questions.",
#  "First your feedback is record. Next everyone's feedback is looked over. With this new answers to your questions or better answers to old questions are made.",
#  "When you give me feedback I record it. Afterwords your feedback along with everyone else's is reviewed. This then becomes new answers or better answers to your questions.",
#  "When you give me feedback I record it. Afterwords your feedback along with everyone else's is reviewed. This feedback is then turned into new questions or improves old questions.",
#  "When you give me feedback I record it. Afterwords your feedback along with everyone else's is reviewed. With this new answers to your questions or better answers to old questions are made.",
#  "When you give me feedback I record it. Once that is done everyone's feedback is looked through. This then becomes new answers or better answers to your questions.",
#  "When you give me feedback I record it. Once that is done everyone's feedback is looked through. This feedback is then turned into new questions or improves old questions.",
#  "When you give me feedback I record it. Once that is done everyone's feedback is looked through. With this new answers to your questions or better answers to old questions are made.",
#  "When you give me feedback I record it. Next everyone's feedback is looked over. This then becomes new answers or better answers to your questions.",
#  "When you give me feedback I record it. Next everyone's feedback is looked over. This feedback is then turned into new questions or improves old questions.",
#  "When you give me feedback I record it. Next everyone's feedback is looked over. With this new answers to your questions or better answers to old questions are made."]

# %%
## variable finder

def var_finder(lst, var_searching, return_var, fail_var):
    var_ = 0
    for i in lst:
        if i == var_searching:
            var_ = 1
            break
    if var_ == 1:
        return (return_var)
    else:
        return (fail_var)

## getting all responses
    
def get_all_responses(var_name):
	list0_, list1_ = [], intents['intents']
	for i in list1_:
		if i['tag'] == var_name:
			for s0_ in i['responses0']:
				for s1_ in i['responses1']:
					for s2_ in i['responses2']:
						list0_.append(s0_ + s1_ + s2_)
	return(list0_)
        

print('Bot is on, say hi!')

## remove this when you are done bridging gate between app and server
name = "Marcos"

res = 'temp'

while True:
	add_to_database = get_all_responses('add to database now')
	message = spell(input('').lower())

	## test variable, remove before release
	if message == 'break':
		print('turning off')
		break

    ## bot training and storing after training
	elif res == var_finder(add_to_database, res, res, False):
		message_0 = input('').lower()
		list_temp = []
		list_temp.append(message)
		list_temp.append(message_0)
		res = get_response([{'intent': 'training done', 'probability': '1'}], intents)[0]
		followups = get_response([{'intent': 'training done', 'probability': '1'}], intents)[1]
		print(res)
		if followups != "":
			print(followups)

	else:
		ints = predict_class(message)
        ## bot is certain enough its the correct response 
		print(float(ints[0]['probability']))
		if float(ints[0]['probability']) > .9:
			res = get_response(ints, intents)[0]
			followups = get_response(ints, intents)[1]
        ## bot is uncertain answer is correct result
		else:
			print(message)
			res = get_response([{'intent': 'bot uncertain', 'probability': '1'}], intents)[0]
			followups = get_response([{'intent': 'bot uncertain', 'probability': '1'}], intents)[1]
		print(res)
		if followups != "":
			print(followups)
# Out:
# Bot is on, say hi!
#  hi
# 0.9984993
# How are you Marcos! Now how may I help you?
# ['I need help with a question.', 'I want to give feedback.', "I'm new!", 'I need help with something else.']
#  I need help with a question.
# 0.9994999
# Can you tell me about the question? Is it a hardware, app, or health question?
# ['I need help with a hardware question.', 'I need help with an APP question.', 'I have a medical question.', 'I need help with something else.']
#  I'm new!
# 0.9999751
# Welcome Marcos ! Do you want me to tell you more?
# ['Can you tell me what you do?', 'Never mind I need help with a question.', 'Can you tell me how you work?', 'What is feedback?', 'How do you learn with my feedback?', 'How do you hadle privacy?', 'What are these up and down arrows?', 'Why does the bot message me?', 'How do I navigate the bot?', 'I need help with something else.']
#  Can you tell me what you do?
# 0.9221255
# I'm here to help in three different ways: first is by answering your questions about the app or hardware, the second way I help is by helping answer your question related to health and medine, and the third is to give you a way to give feedback about the app or hardware.
# ['Can you tell me how you work?', 'What is feedback?', 'How do you learn with my feedback?', 'How do you hadle privacy?', 'What are these up and down arrows?', 'Why does the bot message me?', 'How do I navigate the bot?', 'I need a review on how to use the chatbot', 'I need help with something else.']
#  Can you tell me how you work?
# 0.9927348
# I'm a chatbot that uses machine learning to answer your questions! You can either select a question in the bubbles bellow or type one out. You can also click the view old questions option to see older options and don't forget that you can scroll to see more questions!
# ['What is feedback?', 'How do you learn with my feedback?', 'How do you hadle privacy?', 'What are these up and down arrows?', 'Why does the bot message me?', 'How do I navigate the bot?', 'I need a review on how to use the chatbot', 'Can you tell me what you do?', 'I need help with something else.']
#  What is feedback?
# 0.9995603
# Of the responses possible there are two which will lead to me recording your feedback. The first type of feedback you can give is on the band's user which you can give either after a message appears and asks if you want to give feedback or by seeking it out. The second of which you can give any time through talking to me and it can be about any issue you are having, be it talking to me, a hardware issue, or wanting a feature!
# ['How do you learn with my feedback?', 'How do you hadle privacy?', 'What are these up and down arrows?', 'Why does the bot message me?', 'How do I navigate the bot?', 'I need a review on how to use the chatbot', 'Can you tell me what you do?', 'Can you tell me how you work?', 'I need help with something else.']
#  How do you learn with my feedback?
# 1.0
# First your feedback is record. Next everyone's feedback is looked over. With this new answers to your questions or better answers to old questions are made.
# ['How do you hadle privacy?', 'What are these up and down arrows?', 'Why does the bot message me?', 'How do I navigate the bot?', 'I need a review on how to use the chatbot', 'I need help with something else.', 'Can you tell me what you do?', 'Can you tell me how you work?', 'What is feedback?', 'I need help with something else.']
#  How do you hadle privacy?
# 0.9999995
# The only information I keep is on the feedback you give me. Nothing you ask or type will be stored online so ask whatever you want!
# ['What are these up and down arrows?', 'Why does the bot message me?', 'How do I navigate the bot?', 'I need a review on how to use the chatbot', 'I need help with something else.', 'Can you tell me what you do?', 'Can you tell me how you work?', 'What is feedback?', 'How do you learn with my feedback?', 'I need help with something else.']
#  What are these up and down arrows?
# 1.0
# You will see the up and down arrows for liking and disliking on the center left. These buttons help you tran me immediate with the click of a button. So if there is something I said that helped or something it said that was not helpful press those buttons!
# ['Why does the bot message me?', 'How do I navigate the bot?', 'I need a review on how to use the chatbot', 'I need help with something else.', 'Can you tell me what you do?', 'Can you tell me how you work?', 'What is feedback?', 'How do you learn with my feedback?', 'How do you hadle privacy?', 'I need help with something else.']
#  Why does the bot message me?
# 0.9999999
# I send messages when something is out of the ordinary. First this will inform you to something going on and secondly, will let you comment on what is going on to look at in a future time.
# ['How do I edit the bot message settings?', 'How do I navigate the bot?', 'I need a review on how to use the chatbot', 'I need help with something else.', 'Can you tell me what you do?', 'Can you tell me how you work?', 'What is feedback?', 'How do you learn with my feedback?', 'How do you hadle privacy?', 'I need help with something else.']
#  How do I edit the bot message settings?
# 1.0
# First you navigate to the settings tab located in the ???. Once there you will see bot settings so if you wish to disable it just select if off.
# ['How do I navigate the bot?', 'I need a review on how to use the chatbot', 'I need help with something else.', 'Can you tell me what you do?', 'Can you tell me how you work?', 'What is feedback?', 'How do you learn with my feedback?', 'How do you hadle privacy?', 'Why does the bot message me?', 'Why does the bot message me?', 'I need help with something else.']
#  How do I navigate the bot?
# 0.77013826
# 0.77013826
# how do i navigate the bot?
# Sorry but I don't recognize that. Would you consider helping training me to recognize that? If so type (Y) and if not (N).
# ['Y', 'N', 'I need help with something else.']
#  How do I navigate the bot
# 0.77013826
# 0.77013826
# how do i navigate the bot
# I'm sorry but I don't know how to answer. Could you help train me to answer that? If so type (Y) and if not (N).
# ['Y', 'N', 'I need help with something else.']

# %%
def predict_class(sentence):
	bow = bag_of_words(sentence)
	res = model.predict(np.array([bow]))[0]
	error_threshold = .05
	results = [[i, r] for i, r in enumerate(res) if r > error_threshold]

	results.sort(key=lambda x: x[1], reverse=True)
	return_list = []
	for r in results:
		return_list.append({'intent': classes[r[0]], 'probability': str(r[1])})
	return return_list

predict_class('')[0]
# Out:
# {'intent': 'How to work up down', 'probability': '0.99907'}
